# %%
from tda.auth import easy_client
from tda.client import Client
from tda.streaming import StreamClient

import asyncio
import json

client = easy_client(
    api_key='APIKEY',
    redirect_uri='https://localhost',
    token_path='/tmp/token.json')
stream_client = StreamClient(client, account_id=1234567890)


async def read_stream():
    await stream_client.login()
    await stream_client.quality_of_service(StreamClient.QOSLevel.EXPRESS)

    def print_message(message):
        print(json.dumps(message, indent=4))

    # Always add handlers before subscribing because many streams start sending
    # data immediately after success, and messages with no handlers are dropped.
    stream_client.add_nasdaq_book_handler(print_message)
    await stream_client.nasdaq_book_subs(['GOOG'])

    while True:
        await stream_client.handle_message()


asyncio.run(read_stream())

# %%
positions = [
    {
        "shortQuantity": 1,
        "averagePrice": 7.9344,
        "currentDayCost": 0,
        "currentDayProfitLoss": 0,
        "currentDayProfitLossPercentage": 0,
        "longQuantity": 0,
        "settledLongQuantity": 0,
        "settledShortQuantity": -1,
        "instrument": {
            "assetType": "OPTION",
            "cusip": "0XSP..FG30418000",
            "symbol": "XSP_061623C418",
            "description": "XSP Jun 16 2023 418.0 Call",
            "type": "VANILLA",
            "putCall": "CALL",
            "underlyingSymbol": "$XSP.X"
        },
        "marketValue": -439.18,
        "maintenanceRequirement": 200,
        "previousSessionShortQuantity": 1
    },
    {
        "shortQuantity": 0,
        "averagePrice": 3.1956,
        "currentDayCost": 0,
        "currentDayProfitLoss": 0,
        "currentDayProfitLossPercentage": 0,
        "longQuantity": 1,
        "settledLongQuantity": 1,
        "settledShortQuantity": 0,
        "instrument": {
            "assetType": "OPTION",
            "cusip": "0XSP..PL30362000",
            "symbol": "XSP_042123P362",
            "description": "XSP Apr 21 2023 362.0 Put",
            "type": "VANILLA",
            "putCall": "PUT",
            "underlyingSymbol": "$XSP.X"
        },
        "marketValue": 386.24,
        "maintenanceRequirement": 0,
        "previousSessionLongQuantity": 1
    },
    {
        "shortQuantity": 0,
        "averagePrice": 7.1856,
        "currentDayCost": 0,
        "currentDayProfitLoss": 0,
        "currentDayProfitLossPercentage": 0,
        "longQuantity": 1,
        "settledLongQuantity": 1,
        "settledShortQuantity": 0,
        "instrument": {
            "assetType": "OPTION",
            "cusip": "0XSP..FG30420000",
            "symbol": "XSP_061623C420",
            "description": "XSP Jun 16 2023 420.0 Call",
            "type": "VANILLA",
            "putCall": "CALL",
            "underlyingSymbol": "$XSP.X"
        },
        "marketValue": 388.89,
        "maintenanceRequirement": 0,
        "previousSessionLongQuantity": 1
    },
    {
        "shortQuantity": 1,
        "averagePrice": 3.6244,
        "currentDayCost": 0,
        "currentDayProfitLoss": 0,
        "currentDayProfitLossPercentage": 0,
        "longQuantity": 0,
        "settledLongQuantity": 0,
        "settledShortQuantity": -1,
        "instrument": {
            "assetType": "OPTION",
            "cusip": "0XSP..PL30365000",
            "symbol": "XSP_042123P365",
            "description": "XSP Apr 21 2023 365.0 Put",
            "type": "VANILLA",
            "putCall": "PUT",
            "underlyingSymbol": "$XSP.X"
        },
        "marketValue": -439.32,
        "maintenanceRequirement": 300,
        "previousSessionShortQuantity": 1
    },
    {
        "shortQuantity": 1,
        "averagePrice": 4.0644,
        "currentDayCost": 0,
        "currentDayProfitLoss": 0,
        "currentDayProfitLossPercentage": 0,
        "longQuantity": 0,
        "settledLongQuantity": 0,
        "settledShortQuantity": -1,
        "instrument": {
            "assetType": "OPTION",
            "cusip": "0XSP..RG30362000",
            "symbol": "XSP_061623P362",
            "description": "XSP Jun 16 2023 362.0 Put",
            "type": "VANILLA",
            "putCall": "PUT",
            "underlyingSymbol": "$XSP.X"
        },
        "marketValue": -808.04,
        "maintenanceRequirement": 200,
        "previousSessionShortQuantity": 1
    },
    {
        "shortQuantity": 1,
        "averagePrice": 2.3044,
        "currentDayCost": 0,
        "currentDayProfitLoss": 0,
        "currentDayProfitLossPercentage": 0,
        "longQuantity": 0,
        "settledLongQuantity": 0,
        "settledShortQuantity": -1,
        "instrument": {
            "assetType": "OPTION",
            "cusip": "0XSP..DL30415000",
            "symbol": "XSP_042123C415",
            "description": "XSP Apr 21 2023 415.0 Call",
            "type": "VANILLA",
            "putCall": "CALL",
            "underlyingSymbol": "$XSP.X"
        },
        "marketValue": -132,
        "maintenanceRequirement": 300,
        "previousSessionShortQuantity": 1
    },
    {
        "shortQuantity": 0,
        "averagePrice": 6.2056,
        "currentDayCost": 0,
        "currentDayProfitLoss": 0,
        "currentDayProfitLossPercentage": 0,
        "longQuantity": 1,
        "settledLongQuantity": 1,
        "settledShortQuantity": 0,
        "instrument": {
            "assetType": "OPTION",
            "cusip": "0NVDA.OO30220000",
            "symbol": "NVDA_032423P220",
            "description": "NVDA Mar 24 2023 220.0 Put",
            "type": "VANILLA",
            "putCall": "PUT",
            "underlyingSymbol": "NVDA"
        },
        "marketValue": 630.17,
        "maintenanceRequirement": 0,
        "previousSessionLongQuantity": 1
    },
    {
        "shortQuantity": 0,
        "averagePrice": 1.7556,
        "currentDayCost": 0,
        "currentDayProfitLoss": 0,
        "currentDayProfitLossPercentage": 0,
        "longQuantity": 1,
        "settledLongQuantity": 1,
        "settledShortQuantity": 0,
        "instrument": {
            "assetType": "OPTION",
            "cusip": "0XSP..DL30418000",
            "symbol": "XSP_042123C418",
            "description": "XSP Apr 21 2023 418.0 Call",
            "type": "VANILLA",
            "putCall": "CALL",
            "underlyingSymbol": "$XSP.X"
        },
        "marketValue": 98.35,
        "maintenanceRequirement": 0,
        "previousSessionLongQuantity": 1
    },
    {
        "shortQuantity": 1,
        "averagePrice": 4.6944,
        "currentDayCost": 0,
        "currentDayProfitLoss": 0,
        "currentDayProfitLossPercentage": 0,
        "longQuantity": 0,
        "settledLongQuantity": 0,
        "settledShortQuantity": -1,
        "instrument": {
            "assetType": "OPTION",
            "cusip": "0NVDA.OO30215000",
            "symbol": "NVDA_032423P215",
            "description": "NVDA Mar 24 2023 215.0 Put",
            "type": "VANILLA",
            "putCall": "PUT",
            "underlyingSymbol": "NVDA"
        },
        "marketValue": -476.88,
        "maintenanceRequirement": 0,
        "previousSessionShortQuantity": 1
    },
    {
        "shortQuantity": 0,
        "averagePrice": 3.8156,
        "currentDayCost": 0,
        "currentDayProfitLoss": 0,
        "currentDayProfitLossPercentage": 0,
        "longQuantity": 1,
        "settledLongQuantity": 1,
        "settledShortQuantity": 0,
        "instrument": {
            "assetType": "OPTION",
            "cusip": "0XSP..RG30360000",
            "symbol": "XSP_061623P360",
            "description": "XSP Jun 16 2023 360.0 Put",
            "type": "VANILLA",
            "putCall": "PUT",
            "underlyingSymbol": "$XSP.X"
        },
        "marketValue": 765.65,
        "maintenanceRequirement": 0,
        "previousSessionLongQuantity": 1
    }
]

# %%
import re

short = [i for i in positions if i['shortQuantity'] > 0]
long = [i for i in positions if i['longQuantity'] > 0]
exp = {re.findall('[0-9]{6}', i['instrument']['symbol'])[0] for i in positions}
symbols = {i['instrument']['underlyingSymbol'] for i in positions}
exp

# %%
dfs = list()
import pandas as pd

for sym in symbols:
    pos_sym_list = list()
    for pos in positions:
        if pos['instrument']['underlyingSymbol'] == sym:
            pos_sym_list.append(
                [pos['shortQuantity'], pos['longQuantity'], pos['instrument']['symbol'], pos['instrument']['putCall'],
                 pos['averagePrice'], pos['marketValue']])

    df = pd.DataFrame(pos_sym_list,
                      columns=['shortQuantity', 'longQuantity', 'symbol', 'putCall', 'averagePrice', 'marketValue'])
    dfs.append((sym, df))  #%%
from tda.auth import easy_client
from tda.client import Client
from tda.streaming import StreamClient

import asyncio
import json

client = easy_client(
    api_key='APIKEY',
    redirect_uri='https://localhost',
    token_path='/tmp/token.json')
stream_client = StreamClient(client, account_id=1234567890)


async def read_stream():
    await stream_client.login()
    await stream_client.quality_of_service(StreamClient.QOSLevel.EXPRESS)

    def print_message(message):
        print(json.dumps(message, indent=4))

    # Always add handlers before subscribing because many streams start sending
    # data immediately after success, and messages with no handlers are dropped.
    stream_client.add_nasdaq_book_handler(print_message)
    await stream_client.nasdaq_book_subs(['GOOG'])

    while True:
        await stream_client.handle_message()


asyncio.run(read_stream())

# %%
positions = [
    {
        "shortQuantity": 1,
        "averagePrice": 7.9344,
        "currentDayCost": 0,
        "currentDayProfitLoss": 0,
        "currentDayProfitLossPercentage": 0,
        "longQuantity": 0,
        "settledLongQuantity": 0,
        "settledShortQuantity": -1,
        "instrument": {
            "assetType": "OPTION",
            "cusip": "0XSP..FG30418000",
            "symbol": "XSP_061623C418",
            "description": "XSP Jun 16 2023 418.0 Call",
            "type": "VANILLA",
            "putCall": "CALL",
            "underlyingSymbol": "$XSP.X"
        },
        "marketValue": -439.18,
        "maintenanceRequirement": 200,
        "previousSessionShortQuantity": 1
    },
    {
        "shortQuantity": 0,
        "averagePrice": 3.1956,
        "currentDayCost": 0,
        "currentDayProfitLoss": 0,
        "currentDayProfitLossPercentage": 0,
        "longQuantity": 1,
        "settledLongQuantity": 1,
        "settledShortQuantity": 0,
        "instrument": {
            "assetType": "OPTION",
            "cusip": "0XSP..PL30362000",
            "symbol": "XSP_042123P362",
            "description": "XSP Apr 21 2023 362.0 Put",
            "type": "VANILLA",
            "putCall": "PUT",
            "underlyingSymbol": "$XSP.X"
        },
        "marketValue": 386.24,
        "maintenanceRequirement": 0,
        "previousSessionLongQuantity": 1
    },
    {
        "shortQuantity": 0,
        "averagePrice": 7.1856,
        "currentDayCost": 0,
        "currentDayProfitLoss": 0,
        "currentDayProfitLossPercentage": 0,
        "longQuantity": 1,
        "settledLongQuantity": 1,
        "settledShortQuantity": 0,
        "instrument": {
            "assetType": "OPTION",
            "cusip": "0XSP..FG30420000",
            "symbol": "XSP_061623C420",
            "description": "XSP Jun 16 2023 420.0 Call",
            "type": "VANILLA",
            "putCall": "CALL",
            "underlyingSymbol": "$XSP.X"
        },
        "marketValue": 388.89,
        "maintenanceRequirement": 0,
        "previousSessionLongQuantity": 1
    },
    {
        "shortQuantity": 1,
        "averagePrice": 3.6244,
        "currentDayCost": 0,
        "currentDayProfitLoss": 0,
        "currentDayProfitLossPercentage": 0,
        "longQuantity": 0,
        "settledLongQuantity": 0,
        "settledShortQuantity": -1,
        "instrument": {
            "assetType": "OPTION",
            "cusip": "0XSP..PL30365000",
            "symbol": "XSP_042123P365",
            "description": "XSP Apr 21 2023 365.0 Put",
            "type": "VANILLA",
            "putCall": "PUT",
            "underlyingSymbol": "$XSP.X"
        },
        "marketValue": -439.32,
        "maintenanceRequirement": 300,
        "previousSessionShortQuantity": 1
    },
    {
        "shortQuantity": 1,
        "averagePrice": 4.0644,
        "currentDayCost": 0,
        "currentDayProfitLoss": 0,
        "currentDayProfitLossPercentage": 0,
        "longQuantity": 0,
        "settledLongQuantity": 0,
        "settledShortQuantity": -1,
        "instrument": {
            "assetType": "OPTION",
            "cusip": "0XSP..RG30362000",
            "symbol": "XSP_061623P362",
            "description": "XSP Jun 16 2023 362.0 Put",
            "type": "VANILLA",
            "putCall": "PUT",
            "underlyingSymbol": "$XSP.X"
        },
        "marketValue": -808.04,
        "maintenanceRequirement": 200,
        "previousSessionShortQuantity": 1
    },
    {
        "shortQuantity": 1,
        "averagePrice": 2.3044,
        "currentDayCost": 0,
        "currentDayProfitLoss": 0,
        "currentDayProfitLossPercentage": 0,
        "longQuantity": 0,
        "settledLongQuantity": 0,
        "settledShortQuantity": -1,
        "instrument": {
            "assetType": "OPTION",
            "cusip": "0XSP..DL30415000",
            "symbol": "XSP_042123C415",
            "description": "XSP Apr 21 2023 415.0 Call",
            "type": "VANILLA",
            "putCall": "CALL",
            "underlyingSymbol": "$XSP.X"
        },
        "marketValue": -132,
        "maintenanceRequirement": 300,
        "previousSessionShortQuantity": 1
    },
    {
        "shortQuantity": 0,
        "averagePrice": 6.2056,
        "currentDayCost": 0,
        "currentDayProfitLoss": 0,
        "currentDayProfitLossPercentage": 0,
        "longQuantity": 1,
        "settledLongQuantity": 1,
        "settledShortQuantity": 0,
        "instrument": {
            "assetType": "OPTION",
            "cusip": "0NVDA.OO30220000",
            "symbol": "NVDA_032423P220",
            "description": "NVDA Mar 24 2023 220.0 Put",
            "type": "VANILLA",
            "putCall": "PUT",
            "underlyingSymbol": "NVDA"
        },
        "marketValue": 630.17,
        "maintenanceRequirement": 0,
        "previousSessionLongQuantity": 1
    },
    {
        "shortQuantity": 0,
        "averagePrice": 1.7556,
        "currentDayCost": 0,
        "currentDayProfitLoss": 0,
        "currentDayProfitLossPercentage": 0,
        "longQuantity": 1,
        "settledLongQuantity": 1,
        "settledShortQuantity": 0,
        "instrument": {
            "assetType": "OPTION",
            "cusip": "0XSP..DL30418000",
            "symbol": "XSP_042123C418",
            "description": "XSP Apr 21 2023 418.0 Call",
            "type": "VANILLA",
            "putCall": "CALL",
            "underlyingSymbol": "$XSP.X"
        },
        "marketValue": 98.35,
        "maintenanceRequirement": 0,
        "previousSessionLongQuantity": 1
    },
    {
        "shortQuantity": 1,
        "averagePrice": 4.6944,
        "currentDayCost": 0,
        "currentDayProfitLoss": 0,
        "currentDayProfitLossPercentage": 0,
        "longQuantity": 0,
        "settledLongQuantity": 0,
        "settledShortQuantity": -1,
        "instrument": {
            "assetType": "OPTION",
            "cusip": "0NVDA.OO30215000",
            "symbol": "NVDA_032423P215",
            "description": "NVDA Mar 24 2023 215.0 Put",
            "type": "VANILLA",
            "putCall": "PUT",
            "underlyingSymbol": "NVDA"
        },
        "marketValue": -476.88,
        "maintenanceRequirement": 0,
        "previousSessionShortQuantity": 1
    },
    {
        "shortQuantity": 0,
        "averagePrice": 3.8156,
        "currentDayCost": 0,
        "currentDayProfitLoss": 0,
        "currentDayProfitLossPercentage": 0,
        "longQuantity": 1,
        "settledLongQuantity": 1,
        "settledShortQuantity": 0,
        "instrument": {
            "assetType": "OPTION",
            "cusip": "0XSP..RG30360000",
            "symbol": "XSP_061623P360",
            "description": "XSP Jun 16 2023 360.0 Put",
            "type": "VANILLA",
            "putCall": "PUT",
            "underlyingSymbol": "$XSP.X"
        },
        "marketValue": 765.65,
        "maintenanceRequirement": 0,
        "previousSessionLongQuantity": 1
    }
]

# %%
import re

short = [i for i in positions if i['shortQuantity'] > 0]
long = [i for i in positions if i['longQuantity'] > 0]
exp = {re.findall('[0-9]{6}', i['instrument']['symbol'])[0] for i in positions}
exp

# %%
dfs = list()
import pandas as pd

for sym in symbols:
    pos_sym_list = list()
    for pos in positions:
        if pos['instrument']['underlyingSymbol'] == sym:
            pos_sym_list.append(
                [pos['shortQuantity'], pos['longQuantity'], pos['instrument']['symbol'], pos['instrument']['putCall'],
                 pos['averagePrice'], pos['marketValue']])

    df = pd.DataFrame(pos_sym_list,
                      columns=['shortQuantity', 'longQuantity', 'symbol', 'putCall', 'averagePrice', 'marketValue'])
    dfs.append((sym, df))

# %%
dfs[1][1]

# %%
import pandas as pd
from datetime import datetime, timedelta

api_key = "9IAUTGASW30LAEMELRMRZEG7ICFKI6FM"


def get_positions(acc_number):
    url = f"https://api.tdameritrade.com/v1/accounts/{acc_number}"
    page = requests.get(url=url,
                        params={'fields': "positions",
                                'apikey': api_key})
    print(page.content)

    content = json.loads(page.content)
    #     dfs = list()
    #     for sym in symbols:
    #         pos_sym_list = list()
    #         for pos in positions:
    #             if pos['instrument']['underlyingSymbol'] == sym:
    #                 pos_sym_list.append([pos['shortQuantity'],pos['longQuantity'],pos['instrument']['symbol'],pos['instrument']['putCall'],pos['averagePrice'],pos['marketValue']])

    #         df = pd.DataFrame(pos_sym_list, columns=['shortQuantity','longQuantity','symbol','putCall','averagePrice','marketValue'])
    #         dfs.append((sym,df))
    return dfs


def analyze_positions():
    positions = get_positions()
    short = [i for i in positions if i['shortQuantity'] > 0]
    long = [i for i in positions if i['longQuantity'] > 0]
    exp = {re.findall('[0-9]{6}', i['instrument']['symbol'])[0] for i in positions}
    symbols = {i['instrument']['underlyingSymbol'] for i in positions}
    parse_dfs(positions)


def parse_dfs(dfs):
    for df in dfs:

        # net cost
        net_cost = 0
        side = "credit"
        for i in df[1].iterrows():
            if i[1][0] > 0:
                net_cost += i[1][0] * -i[1][4]
            else:
                net_cost += i[1][1] * i[1][4]
        net_cost = round(net_cost, 4)
        if net_cost > 0: side = "debit"
        print(df[0], f"{net_cost} {side}")


def get_data(underlying: str, strikes: None, dates: None):
    url = f"https://api.tdameritrade.com/v1/marketdata/chains?&symbol={underlying}"
    page = requests.get(url=url,
                        params={'apikey': api_key})
    content = json.loads(page.content)
    df_list = list()
    for date in dates:
        dt = datetime.strptime(date, "%Y-%m-%d")
        diff = dt - datetime.now()
        dte = f"{date}:{diff.days}"
        for strike in strikes:
            str_strike = str(strike) + ".0"
            opt_info = content['callExpDateMap'][dte][str_strike][0]
            info = ['symbol', 'bid', 'ask', 'mark', 'bidSize', 'askSize', 'totalVolume', 'volatility', 'delta', 'gamma',
                    'theta', 'vega', 'rho', 'openInterest', 'timeValue', 'daysToExpiration', 'intrinsicValue']
            for key in list(opt_info.keys()):
                if key not in info: del opt_info[key]
            opt_info['timestamp'] = datetime.now()
            df_list.append(opt_info)

    return df_list


get_positions("498199772")

# %%
import tda
from selenium import webdriver

api_key = "9IAUTGASW30LAEMELRMRZEG7ICFKI6FM"
redirect_url = "https://localhost"
token_path = "tokens"
with webdriver.Chrome() as driver:
    client = tda.auth.client_from_login_flow(driver, api_key, redirect_url, token_path, asyncio=False,
                                             token_write_func=None, enforce_enums=True)

# %%
t =

# %%
import pandas as pd
import requests, json
from datetime import datetime, timedelta


def get_data(underlying: str, strikes: None, dates: None):
    url = f"https://api.tdameritrade.com/v1/marketdata/chains?&symbol={underlying}"
    page = requests.get(url=url,
                        params={'apikey': api_key})
    content = json.loads(page.content)
    df_list = list()
    for date in dates:
        dt = datetime.strptime(date, "%Y-%m-%d")
        diff = dt - datetime.now()
        dte = f"{date}:{diff.days}"
        for strike in strikes:
            str_strike = str(strike) + ".0"
            opt_info = content['callExpDateMap'][dte][str_strike][0]
            info = ['symbol', 'bid', 'ask', 'mark', 'bidSize', 'askSize', 'totalVolume', 'volatility', 'delta', 'gamma',
                    'theta', 'vega', 'rho', 'openInterest', 'timeValue', 'daysToExpiration', 'intrinsicValue']
            for key in list(opt_info.keys()):
                if key not in info: del opt_info[key]
            opt_info['timestamp'] = datetime.now()
            df_list.append(opt_info)

    return df_list


underlying = "AAPL"
strikes = [130, 150, 160]
dates = ['2023-03-17', '2023-03-24', '2023-03-31']
get_data(underlying, strikes, dates)  #%%
dfs[1][1]

# %%
import pandas as pd
from datetime import datetime, timedelta
import tda
from selenium import webdriver
from collections import defaultdict
from io import StringIO


class TD:

    def __init__(self, api_key):
        self.api_key = api_key
        self.conn = None
        redirect_url = "https://localhost"
        token_path = "tokens"
        with webdriver.Chrome() as driver:
            self.client = tda.auth.client_from_login_flow(driver, self.api_key, redirect_url, token_path, asyncio=False,
                                                          token_write_func=None, enforce_enums=True)

    def copy_from_stringio(self, df, table):
        """
        Here we are going save the dataframe in memory
        and use copy_from() to copy it to the table
        """
        # save dataframe to an in memory buffer
        buffer = StringIO()
        df.to_csv(buffer, index_label='id', header=False, index=False)
        buffer.seek(0)
        if not self.conn: self.create_pg_conn()
        conn = self.conn
        cursor = conn.cursor()
        cursor.execute("SET search_path TO options_data")
        try:
            cursor.copy_from(buffer, table, sep=",")
            conn.commit()
        except (Exception, psycopg2.DatabaseError) as error:
            print("Error: %s" % error)
            conn.rollback()
            cursor.close()
            return 1
        print("copy_from_stringio() done")
        cursor.close()

    def create_pg_conn(self):
        self.conn = psycopg2.connect(user="kg",
                                     password="welcome",
                                     host="192.168.0.46",
                                     port="5432",
                                     database="kg")

    def get_positions(self, acc_number):
        page = self.client.get_account(acc_number, fields=tda.client.Client.Account.Fields("positions"))
        # print(page.content)
        content = json.loads(page.content)
        positions = content['securitiesAccount']['positions']
        symbols = {i['instrument']['underlyingSymbol'] for i in positions}
        dfs = list()
        for sym in symbols:
            pos_sym_list = list()
            for pos in positions:
                if pos['instrument']['underlyingSymbol'] == sym:
                    pos_sym_list.append([pos['shortQuantity'], pos['longQuantity'], pos['instrument']['symbol'],
                                         pos['instrument']['putCall'], pos['averagePrice'], pos['marketValue']])

            df = pd.DataFrame(pos_sym_list,
                              columns=['shortQuantity', 'longQuantity', 'symbol', 'putCall', 'averagePrice',
                                       'marketValue'])
            df['quantity'] = df['longQuantity'] - df['shortQuantity']
            del df['longQuantity']
            del df['shortQuantity']
            dfs.append((sym, df))
        return dfs

    def analyze_positions(self):
        positions = get_positions()
        short = [i for i in positions if i['shortQuantity'] > 0]
        long = [i for i in positions if i['longQuantity'] > 0]
        exp = {re.findall('[0-9]{6}', i['instrument']['symbol'])[0] for i in positions}
        symbols = {i['instrument']['underlyingSymbol'] for i in positions}
        entries = parse_dfs(positions)

    def parse_dfs(self, dfs):
        l = list()
        for df in dfs:

            # net cost
            net_cost = 0
            side = "credit"
            for i in df[1].iterrows():
                if i[1][0] > 0:
                    net_cost += i[1][0] * -i[1][4]
                else:
                    net_cost += i[1][1] * i[1][4]
            net_cost = round(net_cost, 4)
            if net_cost > 0: side = "debit"
            l.append(df[0], net_cost, side)
        return l

    def get_data(self, underlying: str, strikes: None, dates: None):
        url = f"https://api.tdameritrade.com/v1/marketdata/chains?&symbol={underlying}"
        page = requests.get(url=url,
                            params={'apikey': api_key})
        content = json.loads(page.content)
        df_list = list()
        for date in dates:
            dte = ""
            for d in content['callExpDateMap'].keys():
                if d[:10] == date: dte = d
            for strike in strikes:
                str_strike = str(strike) + ".0"
                try:
                    opt_info = content['callExpDateMap'][dte][str_strike][0]
                    info = ['symbol', 'bid', 'ask', 'mark', 'bidSize', 'askSize', 'totalVolume', 'volatility', 'delta',
                            'gamma', 'theta', 'vega', 'rho', 'openInterest', 'timeValue', 'daysToExpiration',
                            'intrinsicValue']
                    for key in list(opt_info.keys()):
                        if key not in info: del opt_info[key]
                    opt_info['timestamp'] = datetime.now()
                    df_list.append(opt_info)
                except KeyError:
                    pass
                try:
                    opt_info = content['putExpDateMap'][dte][str_strike][0]
                    info = ['symbol', 'bid', 'ask', 'mark', 'bidSize', 'askSize', 'totalVolume', 'volatility', 'delta',
                            'gamma', 'theta', 'vega', 'rho', 'openInterest', 'timeValue', 'daysToExpiration',
                            'intrinsicValue']
                    for key in list(opt_info.keys()):
                        if key not in info: del opt_info[key]
                    opt_info['timestamp'] = datetime.utcnow()
                    df_list.append(opt_info)
                except KeyError:
                    pass

        return df_list

    def positions_data(self):
        current = td.get_positions("498199772")
        options_list = list()
        for position in current:
            date_dict = defaultdict(list)
            ticker = position[0]
            df = position[1]
            for i in list(df['symbol']):
                groups = re.findall("([A-Z]+)_(.{6})[PC](...)", i)[0]
                date = groups[1]
                date = f"20{date[-2:]}-{date[:2]}-{date[2:-2]}"
                date_dict[date].append(groups[2])
            d = dict(date_dict)
            strikes = [item for sublist in list(d.values()) for item in sublist]
            dates = d.keys()
            df = td.get_data(ticker, strikes, dates)
            options_list.append(df)

        options_detailed = current[0][1].merge(options_port, on='symbol', how='left').drop_duplicates()
        options_detailed['quantity'] = options_detailed['quantity'].astype(int)
        self.copy_from_stringio(options_detailed, "options_positions")


api_key = "9IAUTGASW30LAEMELRMRZEG7ICFKI6FM"
td = TD(api_key)
td.positions_data()
# Out:
# **************************************************************
#
# Opening the login page in a webdriver. Please use this window to log in. Successful login will be detected automatically.
#
# If you encounter any issues, see here for troubleshooting: https://tda-api.readthedocs.io/en/stable/auth.html#troubleshooting
#
# **************************************************************
#
# copy_from_stringio() done

# %%
options_port = pd.DataFrame(options_list[0])
options_port
# Out:
#             symbol    bid    ask   mark  bidSize  askSize  totalVolume  \
# 0   XSP_033123C380  12.62  13.97  12.84      116      116            0
# 1   XSP_033123P380   6.30   6.54   6.61      153      153           21
# 2   XSP_033123C364  24.76  26.24  24.92      125      125            0
# 3   XSP_033123P364   2.58   2.77   2.73      340      340            2
# 4   XSP_033123C350  37.16  38.74  37.32      126      126            0
# ..             ...    ...    ...    ...      ...      ...          ...
# 59  XSP_042123P365   4.69   4.93   4.91      272      272           95
# 60  XSP_042123C415   1.43   1.63   1.46      493      493           17
# 61  XSP_042123P415  27.86  29.47  29.28      126      126            0
# 62  XSP_042123C418   1.02   1.21   1.12      697      697            7
# 63  XSP_042123P418  30.42  32.05  31.93      122      122            1
#
#     volatility  delta  gamma  theta   vega    rho  openInterest  timeValue  \
# 0       27.266  0.616  0.016 -0.263  0.333  0.115             0      15.86
# 1       27.266 -0.384  0.016 -0.228  0.333 -0.079             0       6.50
# 2       30.244  0.816  0.010 -0.213  0.231  0.148             0       6.57
# 3       30.244 -0.183  0.010 -0.181  0.231 -0.038             0       2.34
# 4       32.723  0.914  0.005 -0.147  0.136  0.161             0      16.27
# ..         ...    ...    ...    ...    ...    ...           ...        ...
# 59      26.549 -0.237  0.009 -0.122  0.392 -0.105             0       4.26
# 60      18.252  0.129  0.009 -0.066  0.267  0.052             0       1.56
# 61      18.252 -0.869  0.009 -0.026  0.267 -0.396             0     -10.53
# 62      18.148  0.104  0.008 -0.056  0.230  0.042             0       1.06
# 63      18.148 -0.894  0.008 -0.015  0.230 -0.409             0      -0.08
#
#     daysToExpiration  intrinsicValue                  timestamp
# 0                 17            5.58 2023-03-14 02:12:50.599490
# 1                 17           -5.58 2023-03-14 09:12:50.599503
# 2                 17           21.58 2023-03-14 02:12:50.599511
# 3                 17          -21.58 2023-03-14 09:12:50.599518
# 4                 17           35.58 2023-03-14 02:12:50.599525
# ..               ...             ...                        ...
# 59                38          -20.58 2023-03-14 09:12:50.599848
# 60                38          -29.42 2023-03-14 02:12:50.599854
# 61                38           29.42 2023-03-14 09:12:50.599861
# 62                38          -32.42 2023-03-14 02:12:50.599863
# 63                38           32.42 2023-03-14 09:12:50.599865
#
# [64 rows x 18 columns]

# %%
# Out:
#             symbol putCall  averagePrice  marketValue  quantity   bid   ask  \
# 0   XSP_033123P380     PUT        5.6256       661.00       1.0  6.30  6.54
# 1   XSP_033123P364     PUT        2.3344      -545.08      -2.0  2.58  2.77
# 2   XSP_033123P350     PUT        1.0656       115.41       1.0  1.09  1.23
# 3   XSP_061623C418    CALL        7.9344      -446.05      -1.0  4.43  4.79
# 5   XSP_042123P362     PUT        3.1956       432.76       1.0  4.13  4.36
# 7   XSP_061623C420    CALL        7.1856       396.96       1.0  3.91  4.27
# 8   XSP_042123P365     PUT        3.6244      -491.27      -1.0  4.69  4.93
# 9   XSP_061623P362     PUT        4.0644      -882.02      -1.0  8.45  8.83
# 11  XSP_042123C415    CALL        2.3044      -146.00      -1.0  1.43  1.63
# 12  XSP_042123C418    CALL        1.7556       112.01       1.0  1.02  1.21
# 14  XSP_061623P360     PUT        3.8156       838.03       1.0  8.02  8.39
#
#     mark  bidSize  askSize  ...  delta  gamma  theta   vega    rho  \
# 0   6.61      153      153  ... -0.384  0.016 -0.228  0.333 -0.079
# 1   2.73      340      340  ... -0.183  0.010 -0.181  0.231 -0.038
# 2   1.15      782      782  ... -0.085  0.005 -0.116  0.136 -0.017
# 3   4.46      272      272  ...  0.228  0.009 -0.063  0.594  0.218
# 5   4.33      306      306  ... -0.213  0.008 -0.117  0.369 -0.094
# 7   3.97      289      289  ...  0.209  0.008 -0.059  0.567  0.201
# 8   4.91      272      272  ... -0.237  0.009 -0.122  0.392 -0.105
# 9   8.82      238      238  ... -0.268  0.007 -0.076  0.649 -0.294
# 11  1.46      493      493  ...  0.129  0.009 -0.066  0.267  0.052
# 12  1.12      697      697  ...  0.104  0.008 -0.056  0.230  0.042
# 14  8.38      255      255  ... -0.256  0.006 -0.075  0.633 -0.281
#
#     openInterest  timeValue  daysToExpiration  intrinsicValue  \
# 0              0       6.50                17           -5.58
# 1              0       2.34                17          -21.58
# 2              0       1.06                17          -35.58
# 3              0       7.94                94          -32.42
# 5              0       3.66                38          -23.58
# 7              0       5.30                94          -34.42
# 8              0       4.26                38          -20.58
# 9              0       4.07                94          -23.58
# 11             0       1.56                38          -29.42
# 12             0       1.06                38          -32.42
# 14             0       8.13                94          -25.58
#
#                     timestamp
# 0  2023-03-14 09:12:50.599503
# 1  2023-03-14 09:12:50.599518
# 2  2023-03-14 09:12:50.599532
# 3  2023-03-14 02:12:50.599736
# 5  2023-03-14 09:12:50.599836
# 7  2023-03-14 02:12:50.599671
# 8  2023-03-14 09:12:50.599848
# 9  2023-03-14 09:12:50.599708
# 11 2023-03-14 02:12:50.599854
# 12 2023-03-14 02:12:50.599863
# 14 2023-03-14 09:12:50.599704
#
# [11 rows x 22 columns]

# %%
import pandas as pd
import requests, json
from datetime import datetime, timedelta


def get_data(underlying: str, strikes: None, dates: None):
    url = f"https://api.tdameritrade.com/v1/marketdata/chains?&symbol={underlying}"
    page = requests.get(url=url,
                        params={'apikey': api_key})
    content = json.loads(page.content)
    df_list = list()
    for date in dates:
        dte = ""
        for d in content['callExpDateMap'].keys():
            if d[:10] == date: dte = d

        for strike in strikes:
            str_strike = str(strike) + ".0"
            try:
                opt_info = content['callExpDateMap'][dte][str_strike][0]
                info = ['symbol', 'bid', 'ask', 'mark', 'bidSize', 'askSize', 'totalVolume', 'volatility', 'delta',
                        'gamma', 'theta', 'vega', 'rho', 'openInterest', 'timeValue', 'daysToExpiration',
                        'intrinsicValue']
                for key in list(opt_info.keys()):
                    if key not in info: del opt_info[key]
                opt_info['timestamp'] = datetime.utcnow()
                df_list.append(opt_info)
            except KeyError:
                pass

            try:
                opt_info = content['putExpDateMap'][dte][str_strike][0]
                info = ['symbol', 'bid', 'ask', 'mark', 'bidSize', 'askSize', 'totalVolume', 'volatility', 'delta',
                        'gamma', 'theta', 'vega', 'rho', 'openInterest', 'timeValue', 'daysToExpiration',
                        'intrinsicValue']
                for key in list(opt_info.keys()):
                    if key not in info: del opt_info[key]
                opt_info['timestamp'] = datetime.utcnow()
                df_list.append(opt_info)
            except KeyError:
                pass

    return df_list


underlying = "$XSP.X"
strikes = [400, 350, 365]
dates = ['2023-03-17', '2023-03-24', '2023-03-31']
dict_list = get_data(underlying, strikes, dates)
df = pd.DataFrame(dict_list)
df
# Out:
#             symbol    bid    ask   mark  bidSize  askSize  totalVolume  \
# 0   XSP_031723C400   0.82   0.92   0.78      425      425          444
# 1   XSP_031723P400  13.72  15.31  15.07      125      125           40
# 2   XSP_031723C350  35.60  37.28  35.82      124      124            0
# 3   XSP_031723P350   0.10   0.16   0.13     1326     1326           23
# 4   XSP_031723C365  21.15  22.75  21.43      125      125            0
# 5   XSP_031723P365   0.54   0.63   0.73      816      816            8
# 6   XSP_032423C400   2.22   2.42   2.14      272      272           20
# 7   XSP_032423P400  14.91  16.48  16.20      111      111           22
# 8   XSP_032423C350  36.44  38.08  36.65      123      123            0
# 9   XSP_032423P350   0.60   0.72   0.78      969      969            1
# 10  XSP_032423C365  22.83  24.34  22.89      126      126            0
# 11  XSP_032423P365   1.88   2.07   2.01      374      374           26
# 12  XSP_033123C400   3.00   3.20   2.90      238      238            0
# 13  XSP_033123P400  15.41  16.93  16.62      110      110            7
# 14  XSP_033123C350  37.16  38.74  37.32      126      126            0
# 15  XSP_033123P350   1.09   1.23   1.15      782      782            1
#
#     volatility  delta  gamma  theta   vega    rho  openInterest  timeValue  \
# 0       28.057  0.129  0.017 -0.279  0.092  0.006             0       0.84
# 1       28.057 -0.871  0.017 -0.250  0.092 -0.045             0      -1.99
# 2       41.924  0.981  0.003 -0.113  0.020  0.044             0       5.46
# 3       41.924 -0.019  0.003 -0.091  0.020 -0.001             0       0.35
# 4       37.571  0.906  0.010 -0.314  0.073  0.042             0       0.88
# 5       37.571 -0.094  0.010 -0.290  0.073 -0.005             0       0.67
# 6       25.193  0.220  0.017 -0.226  0.204  0.026             0       2.55
# 7       25.193 -0.780  0.017 -0.195  0.204 -0.101             0      -0.03
# 8       37.377  0.932  0.005 -0.166  0.090  0.103             0       1.68
# 9       37.377 -0.067  0.005 -0.142  0.090 -0.009             0       0.79
# 10      32.772  0.836  0.011 -0.259  0.170  0.096             0       3.00
# 11      32.772 -0.163  0.011 -0.234  0.170 -0.021             0       2.39
# 12      22.458  0.253  0.016 -0.176  0.279  0.048             0       3.15
# 13      22.458 -0.746  0.016 -0.139  0.279 -0.156             0      -0.41
# 14      32.723  0.914  0.005 -0.147  0.136  0.161             0      16.27
# 15      32.723 -0.085  0.005 -0.116  0.136 -0.017             0       1.06
#
#     daysToExpiration  intrinsicValue                  timestamp
# 0                  3          -14.42 2023-03-14 09:10:10.500889
# 1                  3           14.42 2023-03-14 09:10:10.500902
# 2                  3           35.58 2023-03-14 09:10:10.500910
# 3                  3          -35.58 2023-03-14 09:10:10.500917
# 4                  3           20.58 2023-03-14 09:10:10.500924
# 5                  3          -20.58 2023-03-14 09:10:10.500931
# 6                 10          -14.42 2023-03-14 09:10:10.500948
# 7                 10           14.42 2023-03-14 09:10:10.500955
# 8                 10           35.58 2023-03-14 09:10:10.500964
# 9                 10          -35.58 2023-03-14 09:10:10.500972
# 10                10           20.58 2023-03-14 09:10:10.500981
# 11                10          -20.58 2023-03-14 09:10:10.500989
# 12                17          -14.42 2023-03-14 09:10:10.501005
# 13                17           14.42 2023-03-14 09:10:10.501012
# 14                17           35.58 2023-03-14 09:10:10.501020
# 15                17          -35.58 2023-03-14 09:10:10.501027

# %%
import matplotlib.pyplot as plt
def get_options(ticker):
    options_sales = list()
    for sale in open(f"data/{ticker}.txt"):
        o = re.findall('(\d{1,2}\/\d{2}\/\d{2}) (\d{2}:\d{2}:\d{2})\s(\d{1,2}\s[A-Z]{3}\s[\d]{2})\s([\d?.\d+]*)\s([CP])\s(\d{1,3}(?:,\d{3})*|\d{4,})\s(-?(?:\.\d{1,2}|[1-9]\d*(?:\.\d{1,2})?))\s([A-Z0-9]+)\s(-?(?:\.\d{1,2}|[1-9]\d*(?:\.\d{1,2})?)x-?(?:\.\d{1,2}|[1-9]\d*(?:\.\d{1,2})?))\s(-?\d?.\d+)\s(\d+.\d+%|--)\s(\d+.\d+)(\s.+)?'
                       , sale)
        # print(o[0])
        o = o[0]

        if o[-1].strip() == 'Spread':
            # print('hi')
            dt = datetime.strptime(o[0] + " " + o[1], "%m/%d/%y %H:%M:%S")
            options_sales.append([ticker, o[2], o[3], o[4], dt, o[5], o[6], o[7], o[8], o[9], o[10], o[11], True])
        else:
            dt = datetime.strptime(o[0] + " " + o[1], "%m/%d/%y %H:%M:%S")
            options_sales.append([ticker, o[2], o[3], o[4], dt, o[5], o[6], o[7], o[8], o[9], o[10], o[11], False])
    df = pd.DataFrame(options_sales,
                      columns=['ticker','exp_date', 'strike', 'callput', 'time_of_sale', 'quantity',
                               'price', 'exchange', 'market', 'delta', 'implied_volatility', 'spot', 'spread'])
    return df
def copy_from_stringio(df, table):
        """
        Here we are going save the dataframe in memory
        and use copy_from() to copy it to the table
        """
        # save dataframe to an in memory buffer
        buffer = StringIO()
        df.to_csv(buffer, sep='|',index_label='id', header=False, index=False)
        buffer.seek(0)

        conn = psycopg2.connect(user="kg",
                                     password="welcome",
                                     host="192.168.0.46",
                                     port="5432",
                                     database="kg")

        cursor = conn.cursor()
        cursor.execute("SET search_path TO options_data")
        try:
            cursor.copy_from(buffer, table, sep="|")
            conn.commit()
        except (Exception, psycopg2.DatabaseError) as error:
            print("Error: %s" % error)
            conn.rollback()
            cursor.close()
            return 1
        print("copy_from_stringio() done")
        cursor.close()
def get_from_db(ticker):
    conn = psycopg2.connect(user="kg",
                                     password="welcome",
                                     host="192.168.0.46",
                                     port="5432",
                                     database="kg")

    cursor = conn.cursor()
    cursor.execute(f"SELECT  exp_date, strike, time_of_sale, quantity, price, delta, implied_volatility, spot FROM options_data.sales WHERE ticker = '{ticker}'")

    tuples_list = cursor.fetchall()
    cursor.close()
    df = pd.DataFrame(tuples_list, columns=['exp_date','strike','time_of_sale','quantity','price','delta','implied_volatility','spot'])
    return df
def plot_spot_premium(ticker):
    df = get_from_db(ticker)
    premium = df[['exp_date','strike','time_of_sale','quantity','price','delta','implied_volatility','spot']]
    premium['quantity'] = pd.to_numeric(premium["quantity"].str.replace(",",""))
    premium["price"] = pd.to_numeric(premium["price"])
    premium["spot"] = pd.to_numeric(premium["spot"])
    premium['premium'] = premium.quantity * premium.price
    premium['time_of_sale'] = pd.to_datetime(premium['time_of_sale'])
    premium['premium'] = premium['premium'] * 100
    premium.set_index('time_of_sale', inplace=True)
    premium_minute = premium.resample('1T').agg({'spot': 'mean', 'quantity': 'sum', 'premium': 'sum'})

    # filter by premium
    premium_minute.loc[premium_minute['premium'] <= 50000000, 'premium'] = 0

    # Create the plot using matplotlib
    fig, ax = plt.subplots(figsize=(30, 30))
    ax.scatter(premium_minute.index, premium_minute['premium'], s=premium_minute['premium'] ** 0.5, alpha=0.5)
    ax.set_ylabel('Premium')
    ax2 = ax.twinx()
    ax2.plot(premium_minute.index, premium_minute['spot'], color='tab:blue')
    ax.set_xlabel('Time')
    ax2.set_ylabel('Spot Price')
    ax2.tick_params(axis='y', labelcolor='white')
    ax.legend(['Spot Price', 'Option Premium'])
    plt.show()
def import_new_data(ticker):
    df = get_options(ticker)
    copy_from_stringio(df, "sales")

# %%
plot_spot_premium("SPY")

# %%
import_new_data("SPY")
# Out:
# copy_from_stringio() done
